# %%
import os
import pandas as pd
import time
import requests

# %%
os.getcwd()
# Out:
# 'c:\\Users\\refelipe\\Desktop\\personal\\git\\deputyour'

# %% [markdown]
# ### Getting deputy id

# %%
deputies_call = 'https://dadosabertos.camara.leg.br/api/v2/deputados?ordem=ASC&ordenarPor=nome'

# %%
response = requests.get(deputies_call)
data = response.json()

# %%
data
# Out:
# {'dados': [{'id': 204554,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204554',
#    'nome': 'Abílio Santana',
#    'siglaPartido': 'PSC',
#    'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36833',
#    'siglaUf': 'BA',
#    'idLegislatura': 56,
#    'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204554.jpg',
#    'email': None},
#   {'id': 204521,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204521',
#    'nome': 'Abou Anni',
#    'siglaPartido': 'UNIÃO',
#    'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/38009',
#    'siglaUf': 'SP',
#    'idLegislatura': 56,
#    'urlFoto': 'https://www.camara.leg.br/internet/deputado/bandep/204521.jpg',
#    'email': None},
#   {'id': 204379,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/204379',
#    'nome': 'Acácio Favacho',
#    'siglaPartido': 'MDB',
#    'uriPartido': 'https://dadosabertos.camara.leg.br/api/v2/partidos/36899',
# ...

# %%
deputy_ids = [_id['id'] for _id in data['dados']]

# %%
len(deputy_ids)
# Out:
# 513

# %%
deputy_ids[1]
# Out:
# 204521

# %%
years = [2019, 2020, 2021]

dfs_deputy_to_contact = []

count = 0

for deputy_id in deputy_ids:
    
    count += 1

    print(count, ' - ', deputy_id)

    api = 'https://dadosabertos.camara.leg.br/api/v2/deputados/{}/'.format(deputy_id)

    cost_year, cost_month, cost_type, cost_value, cost_code, deputy_unique = [], [], [], [], [], []

    for year in years:

        method = f'despesas?ano={year}&ordem=ASC&ordenarPor=ano'
        url_call = api + method
        time.sleep(2.5)
        response = requests.get(url_call)

        data = response.json()

        # print(count, ' - ', deputy_id, f'- response:{response.status_code}')
        # print(url_call)

        for costs in data['dados']:
            cost_year.append(costs['ano'])
            cost_month.append(costs['mes'])
            cost_type.append(costs['tipoDespesa'])
            cost_value.append(costs['valorDocumento'])
            cost_code.append(costs['codDocumento'])
            deputy_unique.append(deputy_id)

            df = pd.DataFrame({'year': cost_year, 'month': cost_month, 'cost_type': cost_type, 
                                'value': cost_value, 'cost_code': cost_code, 'deputy_id':deputy_unique})
            # print(df)
    df.to_csv('data/csv/{}.csv'.format(deputy_id), sep='|', encoding='utf-8', index=False)
    dfs_deputy_to_contact.append(df)

costs_df = pd.concat(dfs_deputy_to_contact).drop_duplicates()
costs_df.to_csv('data/csv/costs_full.csv', sep='|', encoding='utf-8', index=False)
# Out:
# 1  -  204554
# 2  -  204521
# 3  -  204379
# 4  -  204560
# 5  -  204528
# 6  -  121948
# 7  -  74646
# 8  -  141372
# 9  -  160508
# 10  -  136811
# 11  -  178835
# 12  -  160527
# 13  -  204495
# 14  -  204549
# 15  -  178836
# 16  -  160559
# 17  -  204413
# 18  -  204545
# 19  -  204501
# 20  -  160511
# 21  -  178972
# 22  -  204571
# 23  -  204544
# 24  -  160545
# 25  -  204503
# 26  -  204516
# 27  -  74057
# 28  -  178927
# 29  -  204353
# 30  -  204400
# 31  -  178937
# 32  -  178881
# 33  -  204356
# 34  -  178831
# 35  -  74471
# 36  -  204423
# 37  -  133439
# 38  -  178882
# 39  -  204515
# 40  -  73696
# 41  -  74212
# 42  -  160553
# 43  -  73433
# 44  -  141391
# 45  -  204414
# 46  -  160541
# 47  -  160600
# 48  -  74090
# 49  -  74459
# 50  -  160665
# 51  -  204509
# 52  -  160512
# 53  -  69871
# 54  -  178975
# 55  -  73701
# 56  -  109429
# 57  -  141335
# 58  -  204358
# 59  -  178948
# 60  -  207176
# 61  -  204374
# 62  -  204388
# 63  -  141513
# ...

# %%
costs_df.head()
# Out:
#    year  month                                          cost_type   value  \
# 0  2019      3  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...  154.95
# 1  2019      5  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...  343.48
# 2  2019      6  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...  312.27
# 3  2019      7  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...  191.56
# 4  2019      8  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...  138.61
#
#    cost_code  deputy_id
# 0    6801547     204554
# 1    6839323     204554
# 2    6864448     204554
# 3    6892233     204554
# 4    6915356     204554

# %%
costs_df.groupby(['year','month','cost_type'])['value'].agg('mean').reset_index()
# Out:
#      year  month                                          cost_type  \
# 0    2019      1                          ASSINATURA DE PUBLICAÇÕES
# 1    2019      1                      COMBUSTÍVEIS E LUBRIFICANTES.
# 2    2019      1      CONSULTORIAS, PESQUISAS E TRABALHOS TÉCNICOS.
# 3    2019      1               DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
# 4    2019      1         FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# ..    ...    ...                                                ...
# 209  2021      6                                          TELEFONIA
# 210  2021      7                      COMBUSTÍVEIS E LUBRIFICANTES.
# 211  2021      7               DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
# 212  2021      7  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 213  2021      7                                   SERVIÇOS POSTAIS
#
#             value
# 0     2430.000000
# 1      408.574245
# 2     8995.976949
# 3     8903.132216
# 4       68.255517
# ..            ...
# ...

# %%
#data.to_csv('data/csv/0_costs_by_month.csv', sep='|', encoding='utf-8', index=False)

# %%
#data = pd.read_csv('data/csv/0_costs_by_month.csv', encoding='utf-8', delimiter='|')
#data.rename({'value':'mean'}, inplace=True)

# %%
data.groupby(['year', 'month', 'cost_type']).mean()
# Out:
#                                                                     value
# year month cost_type
# 2019 1     ASSINATURA DE PUBLICAÇÕES                              2430.00
#            COMBUSTÍVEIS E LUBRIFICANTES.                        513986.40
#            CONSULTORIAS, PESQUISAS E TRABALHOS TÉCNICOS.        530762.64
#            DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                1486823.08
#            FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR             1979.41
# ...                                                                   ...
# 2021 6     PASSAGEM AÉREA - REEMBOLSO                             1121.45
#            SERVIÇOS POSTAIS                                        513.17
#            TELEFONIA                                              2003.38
#      7     MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE P...      376.90
#            SERVIÇOS POSTAIS                                        118.25
#
# [213 rows x 1 columns]
