# %%
import pandas as pd
import requests

# %%
data = pd.read_csv('../data/csv/costs_full.csv', encoding='utf-8', delimiter='|')#[['year', 'month', 'cost_type', 'value']]
data.head()
# Out:
#    year  month                                          cost_type   value  \
# 0  2019      3  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...  154.95
# 1  2019      5  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...  343.48
# 2  2019      6  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...  312.27
# 3  2019      7  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...  191.56
# 4  2019      8  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...  138.61
#
#    cost_code  deputy_id
# 0    6801547     204554
# 1    6839323     204554
# 2    6864448     204554
# 3    6892233     204554
# 4    6915356     204554

# %%
data.columns
# Out:
# Index(['year', 'month', 'cost_type', 'value', 'cost_code', 'deputy_id'], dtype='object')

# %%
data.year.value_counts()
# Out:
# 2021    7594
# 2019    7429
# 2020    7316
# Name: year, dtype: int64

# %%
data.groupby(['year','month','cost_type'])['value'].agg(['sum','mean']).reset_index()
# Out:
#      year  month                                          cost_type  \
# 0    2019      1                          ASSINATURA DE PUBLICAÇÕES
# 1    2019      1                      COMBUSTÍVEIS E LUBRIFICANTES.
# 2    2019      1      CONSULTORIAS, PESQUISAS E TRABALHOS TÉCNICOS.
# 3    2019      1               DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
# 4    2019      1         FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR
# ..    ...    ...                                                ...
# 209  2021      6                                          TELEFONIA
# 210  2021      7                      COMBUSTÍVEIS E LUBRIFICANTES.
# 211  2021      7               DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.
# 212  2021      7  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 213  2021      7                                   SERVIÇOS POSTAIS
#
#             sum          mean
# 0       2430.00   2430.000000
# 1     513986.40    408.574245
# 2     530762.64   8995.976949
# ...
